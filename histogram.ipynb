# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# preparing the dataset
numbers=[10,12,16,19,11,20,26,28,30,38,35,34,45,60,68,64,62,70,78,75,79,85,94,95]

#creating the histogram
plt.hist(numbers,bins=[0,20,40,60,80,100])
plt.show()

# %%
# customizing the histogram
plt.hist(numbers,bins=[0,20,40,60,80,100],edgecolor='#000000',color='#FF2331')
plt.title("Histogram Demo")
plt.xlabel("Range of values")
plt.ylabel("Frequency of values")
plt.grid(True)
plt.savefi("Histogram Plot.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d0850d06b428> in <module>
#       5 plt.ylabel("Frequency of values")
#       6 plt.grid(True)
# ----> 7 pltsavefig("Histogram Plot.png")
#       8 plt.show()
#
# NameError: name 'pltsavefig' is not defined
