# %%
import pandas as pd
info = pd.read_csv('local-authority-statistics-march-2020-quarter-csv.csv')
info
# Out:
#      Series_reference   Period Reference_period  Data_value       STATUS  \
# 0         LASQ.SA1AZZ  1992.09        Quarterly        8461        Final
# 1         LASQ.SA1AZZ  1992.12        Quarterly       17144        Final
# 2         LASQ.SA1AZZ  1993.03        Quarterly        4597        Final
# 3         LASQ.SA1AZZ  1993.06        Quarterly       19710        Final
# 4         LASQ.SA1AZZ  1993.09        Quarterly       45352        Final
# ...               ...      ...              ...         ...          ...
# 3481      LASA.SARAZZ  2015.06           Annual     8439907        Final
# 3482      LASA.SARAZZ  2016.06           Annual     8937782        Final
# 3483      LASA.SARAZZ  2017.06           Annual     9497252        Final
# 3484      LASA.SARAZZ  2018.06           Annual     9967807        Final
# 3485      LASA.SARAZZ  2019.06           Annual    10683816  Provisional
#
#         UNITS  MAGNTUDE                           Subject             Group  \
# ...

# %%
type(info)
# Out:
# pandas.core.frame.DataFrame

# %%
info.head()
# Out:
#   Series_reference   Period Reference_period  Data_value STATUS    UNITS  \
# 0      LASQ.SA1AZZ  1992.09        Quarterly        8461  Final  Dollars
# 1      LASQ.SA1AZZ  1992.12        Quarterly       17144  Final  Dollars
# 2      LASQ.SA1AZZ  1993.03        Quarterly        4597  Final  Dollars
# 3      LASQ.SA1AZZ  1993.06        Quarterly       19710  Final  Dollars
# 4      LASQ.SA1AZZ  1993.09        Quarterly       45352  Final  Dollars
#
#    MAGNTUDE                           Subject             Group  \
# 0         3  Local Authority Statistics - LAS  Surplus - Actual
# 1         3  Local Authority Statistics - LAS  Surplus - Actual
# 2         3  Local Authority Statistics - LAS  Surplus - Actual
# 3         3  Local Authority Statistics - LAS  Surplus - Actual
# 4         3  Local Authority Statistics - LAS  Surplus - Actual
#
#                                         Series_title
# 0  Operating surplus/deficit excluding non-operat...
# ...

# %%
info.tail()
# Out:
#      Series_reference   Period Reference_period  Data_value       STATUS  \
# 3481      LASA.SARAZZ  2015.06           Annual     8439907        Final
# 3482      LASA.SARAZZ  2016.06           Annual     8937782        Final
# 3483      LASA.SARAZZ  2017.06           Annual     9497252        Final
# 3484      LASA.SARAZZ  2018.06           Annual     9967807        Final
# 3485      LASA.SARAZZ  2019.06           Annual    10683816  Provisional
#
#         UNITS  MAGNTUDE                           Subject            Group  \
# 3481  Dollars         3  Local Authority Statistics - LAS  Income - Actual
# 3482  Dollars         3  Local Authority Statistics - LAS  Income - Actual
# 3483  Dollars         3  Local Authority Statistics - LAS  Income - Actual
# 3484  Dollars         3  Local Authority Statistics - LAS  Income - Actual
# 3485  Dollars         3  Local Authority Statistics - LAS  Income - Actual
#
#                 Series_title
# 3481  Total operating income
# ...

# %%
info.tail(10)
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS  UNITS  \
# 21819         RTEQ.SNV  2017.12      1141.0        NaN      F  Index
# 21820         RTEQ.SNV  2018.03      1150.0        NaN      F  Index
# 21821         RTEQ.SNV  2018.06      1161.0        NaN      F  Index
# 21822         RTEQ.SNV  2018.09      1170.0        NaN      F  Index
# 21823         RTEQ.SNV  2018.12      1176.0        NaN      F  Index
# 21824         RTEQ.SNV  2019.03      1185.0        NaN      F  Index
# 21825         RTEQ.SNV  2019.06      1196.0        NaN      F  Index
# 21826         RTEQ.SNV  2019.09      1206.0        NaN      F  Index
# 21827         RTEQ.SNV  2019.12      1216.0        NaN      F  Index
# 21828         RTEQ.SNV  2020.03      1228.0        NaN      F  Index
#
#        Magnitude                                  Subject  \
# 21819          0  Retail Trade Deflators (ANZSIC06) - RTE
# 21820          0  Retail Trade Deflators (ANZSIC06) - RTE
# ...

# %%
info.shape
# Out:
# (3486, 10)

# %%
info.info(null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3486 entries, 0 to 3485
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  3486 non-null   object
#  1   Period            3486 non-null   float64
#  2   Reference_period  3486 non-null   object
#  3   Data_value        3486 non-null   int64
#  4   STATUS            3486 non-null   object
#  5   UNITS             3486 non-null   object
#  6   MAGNTUDE          3486 non-null   int64
#  7   Subject           3486 non-null   object
#  8   Group             3486 non-null   object
#  9   Series_title      3486 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 177.1+ KB

# %%
info.mean()
# Out:
# Period          2005.961044
# Data_value    571212.119048
# MAGNTUDE           3.000000
# dtype: float64

# %%
info.median()
# Out:
# Period          2006.06
# Data_value    209893.50
# MAGNTUDE           3.00
# dtype: float64

# %%
info.max()
# Out:
# Series_reference                         LASQ.SSRAZZ
# Period                                       2020.03
# Reference_period                           Quarterly
# Data_value                                  11028568
# STATUS                                       Revised
# UNITS                                        Dollars
# MAGNTUDE                                           3
# Subject             Local Authority Statistics - LAS
# Group                  Surplus - Seasonally Adjusted
# Series_title                  Total operating income
# dtype: object

# %%
info.min()
# Out:
# Series_reference                                     LASA.SA1AZZ
# Period                                                   1992.09
# Reference_period                                          Annual
# Data_value                                               -650085
# STATUS                                                     Final
# UNITS                                                    Dollars
# MAGNTUDE                                                       3
# Subject                         Local Authority Statistics - LAS
# Group                                           Expense - Actual
# Series_title        All government grants and subsidies received
# dtype: object

# %%
info.std()
# Out:
# Period        7.994403e+00
# Data_value    1.008361e+06
# MAGNTUDE      0.000000e+00
# dtype: float64

# %%
info.count()
# Out:
# Series_reference    3486
# Period              3486
# Reference_period    3486
# Data_value          3486
# STATUS              3486
# UNITS               3486
# MAGNTUDE            3486
# Subject             3486
# Group               3486
# Series_title        3486
# dtype: int64

# %%
info.describe()
# Out:
#             Period    Data_value  MAGNTUDE
# count  3486.000000  3.486000e+03    3486.0
# mean   2005.961044  5.712121e+05       3.0
# std       7.994403  1.008361e+06       0.0
# min    1992.090000 -6.500850e+05       3.0
# 25%    1999.060000  6.311300e+04       3.0
# 50%    2006.060000  2.098935e+05       3.0
# 75%    2013.060000  6.868505e+05       3.0
# max    2020.030000  1.102857e+07       3.0

# %% [markdown]
# # rename column

# %%
info = info.rename(columns={'Data_value':'Data'})
info
# Out:
#      Series_reference   Period Reference_period      Data       STATUS  \
# 0         LASQ.SA1AZZ  1992.09        Quarterly      8461        Final
# 1         LASQ.SA1AZZ  1992.12        Quarterly     17144        Final
# 2         LASQ.SA1AZZ  1993.03        Quarterly      4597        Final
# 3         LASQ.SA1AZZ  1993.06        Quarterly     19710        Final
# 4         LASQ.SA1AZZ  1993.09        Quarterly     45352        Final
# ...               ...      ...              ...       ...          ...
# 3481      LASA.SARAZZ  2015.06           Annual   8439907        Final
# 3482      LASA.SARAZZ  2016.06           Annual   8937782        Final
# 3483      LASA.SARAZZ  2017.06           Annual   9497252        Final
# 3484      LASA.SARAZZ  2018.06           Annual   9967807        Final
# 3485      LASA.SARAZZ  2019.06           Annual  10683816  Provisional
#
#         UNITS  MAGNTUDE                           Subject             Group  \
# ...

# %% [markdown]
# # drop the unwanted column

# %%
info = info.drop(columns=['MAGNTUDE'])
info
# Out:
#      Series_reference   Period Reference_period      Data       STATUS  \
# 0         LASQ.SA1AZZ  1992.09        Quarterly      8461        Final
# 1         LASQ.SA1AZZ  1992.12        Quarterly     17144        Final
# 2         LASQ.SA1AZZ  1993.03        Quarterly      4597        Final
# 3         LASQ.SA1AZZ  1993.06        Quarterly     19710        Final
# 4         LASQ.SA1AZZ  1993.09        Quarterly     45352        Final
# ...               ...      ...              ...       ...          ...
# 3481      LASA.SARAZZ  2015.06           Annual   8439907        Final
# 3482      LASA.SARAZZ  2016.06           Annual   8937782        Final
# 3483      LASA.SARAZZ  2017.06           Annual   9497252        Final
# 3484      LASA.SARAZZ  2018.06           Annual   9967807        Final
# 3485      LASA.SARAZZ  2019.06           Annual  10683816  Provisional
#
#         UNITS                           Subject             Group  \
# ...

# %%
df = info[['Series_reference','Period','Reference_period','Data','STATUS','UNITS','Subject',
           'Group','Series_title']].corr()
df
# Out:
#           Period      Data
# Period  1.000000  0.235616
# Data    0.235616  1.000000

# %%
info.Reference_period = info.Reference_period.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-8ea7951dfc59> in <module>
# ----> 1 info.Reference_period = info.Reference_period.astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...
