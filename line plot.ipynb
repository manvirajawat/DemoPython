# %% [markdown]
# # line plot

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([10,8,13,9,11,14,6,4,12,7,5])
y1=np.array([8.04,6.95,7.58,8.81,8.33,9.96,7.24,4.26,10.84,4.82,5.68])
y2=np.array([9.14,8.14,8.74,8.77,9.26,8.10,6.13,3.10,9.13,7.26,4.74])
y3=np.array([7.46,6.77,12.74,7.11,7.81,8.84,6.08,5.39,8.15,6.42,5.75])
x4=np.array([8,8,8,8,8,8,8,19,8,8,8])
y4=np.array([6.58,5.76,7.71,8.84,8.47,7.04,5.25,12.50,5.56,7.91,6.89])
def fit(x):
    return 3+0.5*x
xfit=np.array([np.min(x),np.max(x)])
plt.subplot(221)
plt.plot(x,y1,'ks',xfit,fit(xfit),'r-',lw=2)
plt.axis([2,20,2,14])
plt.setp(plt.gca(),xticklabels=[],yticks=(4,8,12),xticks=(0,10,20))
plt.text(3,12,'I',fontsize=20)

plt.subplot(222)
plt.plot(x,y2,'ks',xfit,fit(xfit),'r-',lw=2)
plt.axis([2,20,2,14])
plt.setp(plt.gca(),xticks=(0,10,20),xticklabels=[],yticks=(4,8,12),yticklabels=[])
plt.text(3,12,'II',fontsize=20)

plt.subplot(223)
plt.plot(x,y3,'ks',xfit,fit(xfit),'r-',lw=2)
plt.axis([2,20,2,14])
plt.setp(plt.gca(),yticks=(4,8,12),xticks=(0,10,20))
plt.text(3,12,'III',fontsize=20)

plt.subplot(224)
plt.plot(x4,y4,'ks',xfit,fit(xfit),'r-',lw=2)
plt.axis([2,20,2,14])
plt.setp(plt.gca(),yticklabels=[],yticks=(4,8,12),xticks=(0,10,20))
plt.text(3,12,'IV',fontsize=20)

pairs=(x,y1),(x,y2),(x,y3),(x4,y4)
for x,y in pairs:
    print('mean=%1.2f,std=%1.2f,r=%1.2f'%(np.mean(y),np.std(y),np.corrcoef(x,y)[0][1]))
# Out:
# mean=7.50,std=1.94,r=0.82
# mean=7.50,std=1.94,r=0.82
# mean=7.50,std=1.93,r=0.82
# mean=7.50,std=1.94,r=0.82

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# defining the dataset
x=np.arange(0,10,0.1)
y=2*x+5

# plotting the datapoints
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# defining the dataset
x=np.arange(0,10,1)
y=2*x+5

# changing the figure
fig=plt.figure(figsize=(10,5))

#plotting the datapoints
plt.plot(x,y,linewidth=2.0,linestyle=":",color="b",alpha=0.5,marker='o')
plt.title("Line Plot Demo")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend(['line 1'],loc='best')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# defining the dataset
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+10

# create two or moe plots in a fig.
plt.subplot(1,2,1)

# plotting the points
plt.plot(x,y1)
plt.title('Graph1')

# create two or moe plots in a fig.
plt.subplot(1,2,2)

# plotting the points
plt.plot(x,y2)
plt.title('Graph2')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# defining the dataset
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+10

# create two or moe plots in a fig.
plt.subplot(1,1,1)

# plotting the points
plt.plot(x,y1)
plt.title('Graph1')

# create two or moe plots in a fig.
plt.subplot(1,2,2)

# plotting the points
plt.plot(x,y2)
plt.title('Graph2')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# defining the dataset
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+10

# create two or moe plots in a fig.
plt.subplot(1,3,1)

# plotting the points
plt.plot(x,y1)
plt.title('Graph1')

# create two or moe plots in a fig.
plt.subplot(1,2,2)

# plotting the points
plt.plot(x,y2)
plt.title('Graph2')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# defining the dataset
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+10

# create two or moe plots in a fig.
plt.subplot(2,2,1)

# plotting the points
plt.plot(x,y1)
plt.title('Graph1')

# create two or moe plots in a fig.
plt.subplot(1,2,2)

# plotting the points
plt.plot(x,y2)
plt.title('Graph2')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# defining the dataset
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+10

# create two or moe plots in a fig.
plt.subplot(3,2,1)

# plotting the points
plt.plot(x,y1)
plt.title('Graph1')

# create two or moe plots in a fig.
plt.subplot(1,2,2)

# plotting the points
plt.plot(x,y2)
plt.title('Graph2')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# defining the dataset
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+10

# create two or moe plots in a fig.
plt.subplot(1,2,2)

# plotting the points
plt.plot(x,y1)
plt.title('Graph1')

# create two or moe plots in a fig.
plt.subplot(1,2,2)

# plotting the points
plt.plot(x,y2)
plt.title('Graph2')

plt.show()
# Out:
# C:\Users\Yograj\anaconda3\lib\site-packages\ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# defining the dataset
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+10

# create two or moe plots in a fig.
plt.subplot(1,2,1)

# plotting the points
plt.plot(x,y1)
plt.title('Graph1')

# create two or moe plots in a fig.
plt.subplot(1,2,1)

# plotting the points
plt.plot(x,y2)
plt.title('Graph2')

plt.show()
# Out:
# C:\Users\Yograj\anaconda3\lib\site-packages\ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# defining the dataset
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+10

# create two or moe plots in a fig.
plt.subplot(1,2,1)

# plotting the points
plt.plot(x,y1)
plt.title('Graph1')

# create two or moe plots in a fig.
plt.subplot(1,3,2)

# plotting the points
plt.plot(x,y2)
plt.title('Graph2')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# defining the dataset
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+10

# create two or moe plots in a fig.
plt.subplot(1,2,1)

# plotting the points
plt.plot(x,y1)
plt.title('Graph1')

# create two or moe plots in a fig.
plt.subplot(1,1,2)

# plotting the points
plt.plot(x,y2)
plt.title('Graph2')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-ba65161acce2> in <module>
#      16
#      17 # create two or moe plots in a fig.
# ---> 18 plt.subplot(1,1,2)
#      19
#      20 # plotting the points
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
# ...
