# %% [markdown]
# # box plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#data preparation
total=[20,4,1,30,20,10,20,70,30,10]
order=[10,3,1,15,17,2,30,44,2,1]
discount=[30,10,20,5,10,20,50,60,20,45]
data=list([total,order,discount])

#plotting the data
plt.boxplot(data,showmeans=True)
plt.title("Box Plot Demo")
plt.grid(True)
plt.show()

# %% [markdown]
# # violin plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#data preparation
total=[20,4,1,30,20,10,20,70,30,10]
order=[10,3,1,15,17,2,30,44,2,1]
discount=[30,10,20,5,10,20,50,60,20,45]
data=list([total,order,discount])

#plotting the data
plt.violinplot(data,showmeans=True,showmedians=True)
plt.title("Violin Plot Demo")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#data preparation
total=[20,4,1,30,20,10,20,70,30,10]
order=[10,3,1,15,17,2,30,44,2,1]
discount=[30,10,20,5,10,20,50,60,20,45]
boolean=[0,1,0,1,1,1,0,1,1,0]
data=list([total,order,discount,boolean])

#plotting the data
plt.violinplot(data,showmeans=True,showmedians=True)
plt.title("Violon Plot Demo")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#data preparation
total=[20,4,1,30,20,10,20,70,30,10]
order=[10,3,1,15,17,2,30,44,2,1]
discount=[30,10,20,5,10,20,50,60,20,45]
boolean=[0,1,0,1,1,1,0,1,1,0]
data=list([total,order,discount,boolean])

#plotting the data
plt.violinplot(boolean,showmeans=True,showmedians=True)
plt.title("Violon Plot Demo")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#data preparation
total=[20,4,1,30,20,10,20,70,30,10]
order=[10,3,1,15,17,2,30,44,2,1]
discount=[30,10,20,5,10,20,50,60,20,45]
boolean=[0,1,0,1,1,1,0,1,1,0]
data=list([total,order,discount,boolean])

#plotting the data
plt.violinplot(total,showmeans=True,showmedians=True)
plt.title("Violon Plot Demo")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#data preparation
total=[20,4,1,30,20,10,20,70,30,10]
order=[10,3,1,15,17,2,30,44,2,1]
discount=[30,10,20,5,10,20,50,60,20,45]
boolean=[0,1,0,1,1,1,0,1,1,0]
data=list([total,order,discount,boolean])

#plotting the data
plt.violinplot(order,showmeans=True,showmedians=True)
plt.title("Violon Plot Demo")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#data preparation
total=[20,4,1,30,20,10,20,70,30,10]
order=[10,3,1,15,17,2,30,44,2,1]
discount=[30,10,20,5,10,20,50,60,20,45]
boolean=[0,1,0,1,1,1,0,1,1,0]
data=list([total,order,discount,boolean])

#plotting the data
plt.violinplot(discount,showmeans=True,showmedians=True)
plt.title("Violon Plot Demo")
plt.grid(True)
plt.show()
